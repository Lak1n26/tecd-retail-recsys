# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1qXixMZJHfTh2UN4gc5R9x4ZZS0wK77We?usp=sharing)

# %% [markdown]
# # TECD-Retail-RecSys Demo Notebook

# %% [markdown]
# ## 1. Setup

# %%
# клонируем репозиторий
# !git clone https://github.com/Lak1n26/tecd-retail-recsys.git
# %cd tecd-retail-recsys
# Out:
# Cloning into 'tecd-retail-recsys'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 35 (delta 1), reused 31 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 293.35 KiB | 9.17 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/tecd-retail-recsys

# %%
# !uv venv
# Out:
# ...
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate

# %%
# !source .venv/bin/activate

# %%
# устанавливаем все необходимые библиотеки
# !uv pip install -e ".[dev]"
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 200 packages in 1.06s
# Prepared 73 packages in 1.27s
# Uninstalled 2 packages in 2ms
# Installed 73 packages in 267ms
#  + aiobotocore==2.26.0
#  + aiohttp-retry==2.9.1
#  + aioitertools==0.13.0
#  + amqp==5.3.1
#  + appdirs==1.4.4
#  + asyncssh==2.22.0
#  + billiard==4.2.4
#  + boto3==1.41.5
#  + botocore==1.41.5
#  + celery==5.6.1
#  + cfgv==3.5.0
#  + click-didyoumean==0.3.1
#  + click-repl==0.3.0
#  + colorama==0.4.6
#  + configobj==5.0.9
#  + databricks-sdk==0.76.0
#  + dictdiffer==0.9.0
#  + diskcache==5.6.3
#  + distlib==0.4.0
#  + docker==7.1.0
#  + dpath==2.2.0
#  + dulwich==0.25.0
#  + dvc==3.65.0
#  + dvc-data==3.17.0
#  + dvc-http==2.32.0
#  + dvc-objects==5.2.0
#  + dvc-render==1.0.2
#  + dvc-s3==3.2.2
#  + dvc-studio-client==0.22.0
#  + dvc-task==0.40.2
#  + fire==0.7.1
#  + flask-cors==6.0.2
#  + flatten-dict==0.4.2
#  + flufl-lock==8.2.0
#  - fsspec==2025.3.0
#  + fsspec==2025.12.0
#  + funcy==2.0
# ...

# %%
# загружаем данные
# !dvc pull
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#  42% 5.60M/13.4M [00:00<00:00, 9.61MB/s{'info': ''}]
#
#
#
#
#
#
#  52% 1.80M/3.48M [00:00<00:00, 18.8MB/s{'info': ''}]
#
#
#
#
#
#
#
#  41% 110M/267M [00:07<00:10, 15.6MB/s{'info': ''}]
#
#
#
#
#
#  87% 8.57M/9.82M [00:00<00:00, 14.9MB/s{'info': ''}]
#
#
#
#
#
#
#
# Fetching from https:  55% 128/234 [00:18<00:11,  8.94file/s{'info': ''}]
#
#
#
#
#  49% 6.52M/13.4M [00:00<00:00, 9.62MB/s{'info': ''}]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  42% 112M/267M [00:07<00:10, 15.2MB/s{'info': ''}]
#
#   1% 63.4k/7.22M [00:00<00:37, 200kB/s{'info': ''}]
#
#
#   0% 0.00/1.37M [00:00<?, ?B/s]
#
#
#   0% 0.00/1.37M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#  55% 7.43M/13.4M [00:00<00:00, 9.60MB/s{'info': ''}]
#
#
#
#
#
#
#
#  42% 113M/267M [00:07<00:10, 14.8MB/s{'info': ''}]
#
#
#
# Fetching from https:  56% 130/234 [00:18<00:10,  9.84file/s{'info': ''}]
#
#
#   0% 0.00/11.9M [00:00<?, ?B/s]
#
#
#   0% 0.00/11.9M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
# ...

# %% [markdown]
# ## 2. Train

# %%
# препроцессинг данных
# !tecd-recsys preprocess
# Out:
# 2025-12-30 21:51:57,868 - tecd_retail_recsys.data.preprocessing - INFO - Starting data preprocessing...
# 2025-12-30 21:51:57,868 - tecd_retail_recsys.data.preprocessing - INFO - Loading retail events from day 1259 to 1308
# Loading data: 100% 50/50 [00:20<00:00,  2.42it/s]
# 2025-12-30 21:52:23,736 - tecd_retail_recsys.data.preprocessing - INFO - Loaded 80,140,141 total events
# 2025-12-30 21:52:29,791 - tecd_retail_recsys.data.preprocessing - INFO - Filtered to 1,146,940 events with action_type='added-to-cart'
# 2025-12-30 21:52:33,190 - tecd_retail_recsys.data.preprocessing - INFO - After filtering (min_user=5, min_item=5): 1,017,782 events, 26,401 users, 36,136 items
# 2025-12-30 21:52:33,454 - tecd_retail_recsys.data.preprocessing - INFO - Created mappings: 26401 users, 36136 items
# ...

# %%
# обучение модели на 2 эпохах
# !tecd-recsys train --overrides="train.epochs=2"
# Out:
# Streaming output truncated to the last 5000 lines.
#                                                                  train_loss_epo…
# Epoch 1/1  ━━━━━━━━━━━━━━╺ 19473/20164 0:10:28 •       32.14it/s v_num: 0.000
#                                        0:00:22                   train_loss_ste…
#                                                                  0.000
#                                                                  val_hit_rate_1…
#                                                                  0.168
#                                                                  train_loss_epo…
# Epoch 1/1  ━━━━━━━━━━━━━━╺ 19474/20164 0:10:28 •       32.14it/s v_num: 0.000
#                                        0:00:22                   train_loss_ste…
#                                                                  0.000
#                                                                  val_hit_rate_1…
# ...

# %%
# оценка на тестовых данных
# !tecd-recsys evaluate --checkpoint=outputs/checkpoints/epoch=0-val_hit_rate_100=0.1680.ckpt
# Out:
# 2025-12-30 22:18:41,759 - tecd_retail_recsys.data.dataset - INFO - Loading existing processed data...
# 2025-12-30 22:18:42,236 - tecd_retail_recsys.data.preprocessing - INFO - Loaded processed data from data/processed/processed_data.pkl
# 2025-12-30 22:18:42,239 - tecd_retail_recsys.data.dataset - INFO - Created eval dataset with 2823 users
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 2025-12-30 22:18:42,680 - tecd_retail_recsys.data.dataset - INFO - Loading existing processed data...
# 2025-12-30 22:18:43,104 - tecd_retail_recsys.data.preprocessing - INFO - Loaded processed data from data/processed/processed_data.pkl
# ...

# %%
# генерация рекомендаций
# !tecd-recsys infer --checkpoint=outputs/checkpoints/epoch=0-val_hit_rate_100=0.1680.ckpt --output=recommendations.csv
# Out:
# 2025-12-30 22:19:12,991 - tecd_retail_recsys.infer - INFO - Starting inference pipeline...
# 2025-12-30 22:19:13,007 - tecd_retail_recsys.infer - INFO - Using device: cuda
# 2025-12-30 22:19:13,736 - tecd_retail_recsys.data.preprocessing - INFO - Loaded processed data from data/processed/processed_data.pkl
# 2025-12-30 22:19:13,736 - tecd_retail_recsys.infer - INFO - Loading model from outputs/checkpoints/epoch=0-val_hit_rate_100=0.1680.ckpt
# 2025-12-30 22:19:14,289 - tecd_retail_recsys.infer - INFO - Generating recommendations for 3647 users
# Generating recommendations: 100% 3647/3647 [00:18<00:00, 197.55it/s]
# 2025-12-30 22:19:33,457 - tecd_retail_recsys.infer - INFO - Saved recommendations to recommendations.csv
# 2025-12-30 22:19:33,476 - tecd_retail_recsys.infer - INFO - Inference complete!
# 2025-12-30 22:19:33,528 - tecd_retail_recsys.commands - INFO - Generated recommendations for 3647 users
